# %%
import os
from skimage.metrics import structural_similarity as ssim
import cv2
import random
import numpy as np
import matplotlib.pyplot as plt
from pulp import LpMaximize, LpProblem, LpStatus, lpSum, LpVariable
# from scipy.optimize import linprog

# %%
def eve_distortion(eve_intensities): #from the reconstructed image in uint8 type
    feve_intensities = eve_intensities.astype(np.float)
    fintensities = intensities.astype(np.float)
    dif = (fintensities -  feve_intensities)
    eve_dist_mat = dif**2
    occurance_sum = height*width #?!
    eve_dist = eve_dist_mat.sum()/occurance_sum
    return eve_dist

# %% [markdown]
# # Prepare Image Data

# %%
image_name = 'nature'
img_file = image_name + '.tif'
intensities = cv2.imread(img_file, cv2.IMREAD_GRAYSCALE)
height = np.shape(intensities)[0]
width = np.shape(intensities)[1]
imf = np.float32(intensities)

'''From scratch'''
#     all_nq_ac = []
#     all_dcs = []
#     for i in range(0,int(height/8)):
#         print(i)
#         for j in range(0,int(width/8)):
#             blk = imf[8*i:8*(i+1), 8*j:8*(j+1)]
#             shifted_blk = blk - 128 #level_shift for dct
#             dct = cv2.dct(shifted_blk)
#             nq_coef = np.round(dct)
#             nq_coef_dc = nq_coef[0,0]
#             nq_coef_ac = np.delete(nq_coef, [0,0])

#             all_dcs = np.append(all_dcs, nq_coef_dc)
#             all_nq_ac = np.append(all_nq_ac, nq_coef_ac)


#     dcs_file_name = image_name + '_dcs.npy'        
#     np.save(dcs_file_name, all_dcs)        
#     acs_file_name = image_name + '_acs.npy'        
#     np.save(acs_file_name, all_nq_ac)
'''...........................................'''

''' If saved already, so comment the dct part'''
dcs_file_name = image_name + '_dcs.npy' 
acs_file_name = image_name + '_acs.npy'
all_dcs = np.load(dcs_file_name)
all_nq_ac = np.load(acs_file_name)
'''...........................................'''
# Out:
# '...........................................'

# %%
ac_values, ac_counts = np.unique(all_nq_ac, return_counts=True)
ac_values_dic = {}
ac_counts_dic = {}
ac_bits_all_sizes = []
for i in range(1,11):
    neg_part = range(-(2**i-1), -2**(i-1)+1)
    pos_part = range(2**(i-1), 2**i)
    values_in_size = np.append(neg_part,pos_part)
    ac_values_dic[i] = values_in_size
    
    counts_in_size = np.zeros(np.size(values_in_size))
    for j in range(np.size(values_in_size)):
        if values_in_size[j] in ac_values:
            position_in_counts = np.where(
                ac_values == values_in_size[j])
            counts_in_size[j] = ac_counts[position_in_counts]
            
    ac_counts_dic[i] = counts_in_size
    
    #Rate
    ac_bits_in_size = sum(counts_in_size)*i
    ac_bits_all_sizes = np.append(ac_bits_all_sizes, ac_bits_in_size)
total_ac_bits = sum(ac_bits_all_sizes)

ac_prbs = ac_counts/sum(ac_counts)


n0 = 0
pos0 = np.where(ac_values == 0)
ac_values_n0 = ac_values.copy()
ac_counts_n0 = ac_counts.copy()
ac_values_n0 = np.delete(ac_values_n0, pos0)
ac_counts_n0 = np.delete(ac_counts_n0, pos0)


# select 'num' from the middle and sides
num = 256
part1 = ac_values_n0[0:int(num/4)]
neg1_ind = np.where(ac_values_n0 == -1)[0]
part2 = ac_values_n0[int(neg1_ind-int(num/4)+1):\
                     int(neg1_ind+int(num/4)+1)]
part3 = np.append(ac_values_n0[-int(num/4):-1], ac_values_n0[-1])
selected_values_1 = np.append(part1, part2)
selected_values = np.append(selected_values_1, part3)

part1_c = ac_counts_n0[0:int(num/4)]
part2_1_c = ac_counts_n0[int(neg1_ind-int(num/4)+1):int(neg1_ind+1)]
part2_2_c = ac_counts_n0[int(neg1_ind+1):int(neg1_ind+int(num/4)+1)]
part2_c = np.append(part2_1_c, part2_2_c)
part3_c = np.append(ac_counts_n0[-int(num/4):-1], ac_counts_n0[-1])
selected_counts_1 = np.append(part1_c, part2_c)
selected_counts = np.append(selected_counts_1, part3_c)

org_ac_values_n0 = ac_values_n0.copy()
org_ac_counts_n0 = ac_counts_n0.copy()

# Taking care of not selected values, their pairs
ns_part1 = ac_values_n0[int(num/4):int(neg1_ind-int(num/4)+1)]
ns_part2 = ac_values_n0[int(neg1_ind+int(num/4)+1):\
                       -int(num/4)]
ns_values = np.append(ns_part1, ns_part2)

ns_pairs_elements1 = []
ns_pairs_elements2 = []
no_pair_elements_neg = []
no_pair_elements_pos = []
for i in ns_part1:
    i_size = np.floor(np.log2(abs(i)))+1
    bs_pair = i+2**i_size-1+2**(i_size-1)
    if bs_pair in ns_part2:
        ns_pairs_elements1 = np.append(ns_pairs_elements1,i)
        ns_pairs_elements2 = np.append(ns_pairs_elements2,bs_pair)
    else:
        no_pair_elements_neg = np.append(no_pair_elements_neg, i)

for i in ns_part2:
    if not i in ns_pairs_elements2:
        no_pair_elements_pos = np.append(no_pair_elements_pos, i)
        
no_pair_min_len = min(len(no_pair_elements_neg),\
                      len(no_pair_elements_pos))
no_pair_elements1 = no_pair_elements_neg[0:no_pair_min_len]
no_pair_elements2 = no_pair_elements_pos[0:no_pair_min_len]

extra_elements_1 =  no_pair_elements_neg[no_pair_min_len:\
                                        len(no_pair_elements_neg)]
extra_elements_2 =  no_pair_elements_pos[no_pair_min_len:\
                                        len(no_pair_elements_pos)]
extra_elements = np.append(extra_elements_1, extra_elements_2)

extra_half_ind = int(np.floor(len(extra_elements)/2))
extra_elements1 = extra_elements[0:extra_half_ind]
# extra_elements2 = extra_elements[extra_half_ind:]
extra_elements2 = extra_elements[extra_half_ind:-1]

sac_values_n0 = selected_values
sac_counts_n0 = selected_counts

# %% [markdown]
# # Optimization Parameters

# %%
'''This cell takes time'''

var = sac_values_n0.copy()
prbs = sac_counts_n0/sum(sac_counts_n0)

cells_num = np.size(var)

all_yijs = []
all_dijs = []
all_prb0s = []
all_entropies = []
for i in range(0,cells_num-1):
    for j in range(i+1,cells_num):
        yi = var[i]
        yj = var[j]
        possible_dij = 0.5*(
          var[i]**2*prbs[i] + yi**2*prbs[i] - yi*2*var[i]*prbs[i]\
        + var[j]**2*prbs[j] + yi**2*prbs[j] - yi*2*var[j]*prbs[j]\
        + var[i]**2*prbs[i] + yj**2*prbs[i] - yj*2*var[i]*prbs[i]\
        + var[j]**2*prbs[j] + yj**2*prbs[j] - yj*2*var[j]*prbs[j])
        
        all_dijs = np.append(all_dijs, possible_dij)
                
        possible_prb0 = max(prbs[j],prbs[i])
        all_prb0s = np.append(all_prb0s, possible_prb0)
        
        sum_prbs = prbs[j]+prbs[i]
        pair_entropy = -sum_prbs*np.log2(sum_prbs)
        all_entropies = np.append(all_entropies, pair_entropy)

######### ######### ######### ######### ######### ######### ##############        
all_length = int(cells_num * (cells_num-1) / 2)

A_eq = np.zeros([cells_num, all_length])
k = 0
for i in range(0, cells_num-1):
    for j in range(i+1,cells_num):
        A_eq[i,k]=1
        k+=1
k = 0
for j in range(1, cells_num):
    for i in range (j,cells_num):
        A_eq[i,k]=1
        k+=1

# %% [markdown]
# # Creating Model

# %%
# Define the model
model = LpProblem(name="pulp_milp", sense=LpMaximize)

# Define the decision variables
x = {i: LpVariable(name=f"x{i}", lowBound=0, cat="Integer") for i in range(1, all_length+1)}

# %%
'''DO NOT RUN'''
'''Just this cell takes most of the time'''
# Add constraints
for i in range(0,np.shape(A_eq)[0]):
    model += (lpSum(list(x.values())*A_eq[i,:]) == 1)

# %% [markdown]
# # List of Lambdas

# %%
Lambdas1 = np.arange(0, 100000, 10000)
Lambdas2 = np.arange(100000, 160000, 5000)
Lambdas3 = np.arange(160000, 192730, 1000)
Lambdas4 = [192730,192731]
Lambdas5 = np.arange(193000, 200000, 500)
Lambdas6 = np.arange(200000, 300000, 5000)
Lambdas7 = np.arange(300000, 700000, 50000)

Lambdas = np.concatenate(
    (Lambdas1, Lambdas2, Lambdas3, Lambdas4,
     Lambdas5, Lambdas6, Lambdas7), axis = 0)
problematic_lambdas = np.array([70000, 80000, 167000, 185000])
Lambdas = np.setdiff1d(Lambdas, problematic_lambdas)
len(Lambdas)
# Out:
# 95

# %%
Lambdas1 = np.arange(100000, 200000, 10000)
Lambdas = Lambdas1

# %%
pairs_all_lambdas = []
mip_pairs_show_dic = {}
opt_pairs_prbs_lambda_dic = {}
eve_msb0_dist_db_dic = {}
eve_msb1_dist_db_dic = {}
optimized_ac_bits_dic = {}
rate_increase_dic = {}
optimized_entropy_dic = {}

avg_psnrs = []
psnr_msb0s = []
psnr_msb1s = []
entropies = []
rate_increases = []
ac_dist_total_dbs = []

# Set the objective
Omega = 1
# Lambdas = np.arange(192730.51,192730.52,0.0001)
# Lambdas = [0, 100000, 200000]
for Lambda in Lambdas:
    print('lambda=',Lambda)
    mip_pairs_show = []
    model += lpSum((Omega * all_dijs - Lambda * all_entropies\
                   )*list(x.values()))


    # Solve the optimization problem
    status = model.solve()

#     # Get the results
#     print(f"status: {model.status}, {LpStatus[model.status]}")
#     print(f"objective: {model.objective.value()}")


    x01 = [] 
    for var in x.values(): 
        x01 = np.append(x01, var.value())

#     print('check', np.unique(x01))
##################################################################
       
    var = sac_values_n0.copy()

    mip_pairs = x01

    k = 0
    mip_xx1 = np.zeros([cells_num, cells_num])
    for i in range(0,cells_num):
        for j in range(i+1,cells_num):
            mip_xx1[i,j] = mip_pairs[k]
            k +=1


    mip_pairs_show = np.array(np.where(mip_xx1 == 1))

    true_pairs_show_p1 = []
    for i in mip_pairs_show[0]:
        true_pairs_show1 = var[int(i)]
        true_pairs_show_p1 = np.append(true_pairs_show_p1, 
                                       true_pairs_show1)

    true_pairs_show_p2 = []
    for i in mip_pairs_show[1]:
        true_pairs_show1 = var[int(i)]
        true_pairs_show_p2 = np.append(true_pairs_show_p2, 
                                       true_pairs_show1)

    true_pairs_show = [true_pairs_show_p1, true_pairs_show_p2]

    mip_pairs_show = true_pairs_show

    unique_opt_val = np.unique(mip_pairs_show)
#     print('check', np.unique(unique_opt_val - sac_values_n0))
#     print('just selected pairs\n', np.transpose(mip_pairs_show))    ################################################################    
    # Attaching not optimized elements
    # Return to original ac_values_n0 after optimization
    mip_pairs_show[0]= np.append(mip_pairs_show[0], ns_pairs_elements1)
    mip_pairs_show[0]= np.append(mip_pairs_show[0], no_pair_elements1)
    mip_pairs_show[0]= np.append(mip_pairs_show[0], extra_elements1)

    mip_pairs_show[1]= np.append(mip_pairs_show[1], ns_pairs_elements2)
    mip_pairs_show[1]= np.append(mip_pairs_show[1], no_pair_elements1)
    mip_pairs_show[1]= np.append(mip_pairs_show[1], extra_elements2)
    
    if len(mip_pairs_show[0]) != len(mip_pairs_show[1]):
        i = np.argmax([len(mip_pairs_show[0]), len(mip_pairs_show[1])])
        mip_pairs_show[i] = np.delete(mip_pairs_show[i], -1)

    prbs = []
    ac_values_n0 = org_ac_values_n0.copy()
    ac_counts_n0 = org_ac_counts_n0.copy()
    prbs = ac_counts_n0/sum(ac_counts_n0)  
    
#############################################################    
    ##### For Lambdas
    mip_pairs_show_dic[Lambda] = mip_pairs_show

    pairs_show_file_name = image_name + '_pairs_' +str(Lambda)+'.npy'
    np.save(pairs_show_file_name, mip_pairs_show)
# Out:
# lambda= 100000
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/mehr/anaconda3/lib/python3.9/site-packages/pulp/apis/../solverdir/cbc/linux/64/cbc /tmp/f0f17eb87c754c3fa94d01e81bbdbd06-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/f0f17eb87c754c3fa94d01e81bbdbd06-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 261 COLUMNS
# At line 163462 RHS
# At line 163719 BOUNDS
# At line 196360 ENDATA
# Problem MODEL has 256 rows, 32640 columns and 65280 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is -345130 - 0.29 seconds
# Cgl0004I processed model has 256 rows, 32640 columns (32640 integer (32640 of which binary)) and 65280 elements
# Cbc0038I Initial state - 12 integers unsatisfied sum - 6
# Cbc0038I Pass   1: suminf.    4.00000 (8) obj. 345175 iterations 506
# Cbc0038I Pass   2: suminf.    4.00000 (8) obj. 345175 iterations 21
# Cbc0038I Pass   3: suminf.    4.00000 (8) obj. 345175 iterations 214
# Cbc0038I Pass   4: suminf.    0.00000 (0) obj. 444570 iterations 569
# Cbc0038I Solution found of 444570
# Cbc0038I Before mini branch and bound, 32421 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 256 rows 32640 columns, reduced to 12 rows 23 columns
# Cbc0038I Mini branch and bound improved solution from 444570 to 345141 (1.20 seconds)
# Cbc0038I Round again with cutoff of 345140
# Cbc0038I Reduced cost fixing fixed 26630 variables on major pass 2
# Cbc0038I Pass   5: suminf.    3.00000 (6) obj. 345134 iterations 103
# Cbc0038I Pass   6: suminf.    3.00000 (6) obj. 345134 iterations 61
# Cbc0038I Pass   7: suminf.    3.00000 (9) obj. 345140 iterations 126
# Cbc0038I Pass   8: suminf.    3.00000 (9) obj. 345140 iterations 9
# Cbc0038I Pass   9: suminf.    3.00000 (9) obj. 345140 iterations 44
# Cbc0038I Pass  10: suminf.    3.81378 (9) obj. 345140 iterations 227
# Cbc0038I Pass  11: suminf.    3.00000 (6) obj. 345134 iterations 100
# Cbc0038I Pass  12: suminf.    3.00000 (6) obj. 345134 iterations 100
# Cbc0038I Pass  13: suminf.    0.00000 (0) obj. 345140 iterations 198
# Cbc0038I Solution found of 345140
# Cbc0038I Before mini branch and bound, 32612 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 256 rows 32640 columns, reduced to 4 rows 6 columns
# Cbc0038I Mini branch and bound improved solution from 345140 to 345140 (1.43 seconds)
# Cbc0038I Round again with cutoff of 345138
# Cbc0038I Reduced cost fixing fixed 27379 variables on major pass 3
# Cbc0038I Pass  14: suminf.    3.00000 (6) obj. 345134 iterations 0
# Cbc0038I Pass  15: suminf.    3.00000 (6) obj. 345134 iterations 136
# Cbc0038I Pass  16: suminf.    3.00000 (6) obj. 345134 iterations 138
# Cbc0038I Pass  17: suminf.    3.00000 (6) obj. 345134 iterations 79
# Cbc0038I Pass  18: suminf.    3.00000 (6) obj. 345134 iterations 144
# Cbc0038I Pass  19: suminf.    3.00000 (9) obj. 345138 iterations 185
# Cbc0038I Pass  20: suminf.    3.00000 (6) obj. 345137 iterations 131
# Cbc0038I Pass  21: suminf.    2.89263 (7) obj. 345138 iterations 160
# Cbc0038I Pass  22: suminf.    2.89263 (7) obj. 345138 iterations 17
# Cbc0038I Pass  23: suminf.    3.00000 (6) obj. 345137 iterations 211
# Cbc0038I Pass  24: suminf.    3.00000 (6) obj. 345137 iterations 36
# Cbc0038I Pass  25: suminf.    2.89263 (7) obj. 345138 iterations 172
# Cbc0038I Pass  26: suminf.    1.15739 (4) obj. 345138 iterations 240
# Cbc0038I Pass  27: suminf.    0.73163 (9) obj. 345138 iterations 327
# Cbc0038I Pass  28: suminf.    3.00000 (6) obj. 345133 iterations 269
# Cbc0038I Pass  29: suminf.    3.00000 (6) obj. 345138 iterations 92
# Cbc0038I Pass  30: suminf.    3.00000 (9) obj. 345138 iterations 184
# Cbc0038I Pass  31: suminf.    3.00000 (9) obj. 345138 iterations 58
# Cbc0038I Pass  32: suminf.    4.00000 (8) obj. 345138 iterations 291
# Cbc0038I Pass  33: suminf.    3.00000 (9) obj. 345138 iterations 214
# Cbc0038I Pass  34: suminf.    3.00000 (9) obj. 345138 iterations 138
# Cbc0038I Pass  35: suminf.    3.00000 (9) obj. 345138 iterations 123
# Cbc0038I Pass  36: suminf.    3.00000 (9) obj. 345138 iterations 8
# Cbc0038I Pass  37: suminf.    1.66571 (9) obj. 345138 iterations 66
# Cbc0038I Pass  38: suminf.    1.36955 (7) obj. 345138 iterations 192
# Cbc0038I Pass  39: suminf.    3.00000 (6) obj. 345135 iterations 317
# Cbc0038I Pass  40: suminf.    3.00000 (6) obj. 345135 iterations 149
# Cbc0038I Pass  41: suminf.    3.00000 (6) obj. 345134 iterations 47
# Cbc0038I Pass  42: suminf.    3.00000 (6) obj. 345134 iterations 172
# Cbc0038I Pass  43: suminf.    3.00000 (6) obj. 345134 iterations 91
# Cbc0038I Rounding solution of 345136 is better than previous of 345140
#
# Cbc0038I Before mini branch and bound, 32588 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 256 rows 32640 columns, reduced to 2 rows 3 columns
# Cbc0038I Mini branch and bound improved solution from 345136 to 345136 (2.22 seconds)
# Cbc0038I Round again with cutoff of 345134
# Cbc0038I Reduced cost fixing fixed 29070 variables on major pass 4
# Cbc0038I Pass  43: suminf.    3.00000 (6) obj. 345131 iterations 57
# Cbc0038I Pass  44: suminf.    3.00000 (6) obj. 345131 iterations 191
# Cbc0038I Pass  45: suminf.    3.00000 (6) obj. 345131 iterations 66
# Cbc0038I Pass  46: suminf.    3.00000 (6) obj. 345131 iterations 90
# Cbc0038I Pass  47: suminf.    3.00000 (6) obj. 345131 iterations 108
# Cbc0038I Pass  48: suminf.    3.00000 (6) obj. 345133 iterations 66
# Cbc0038I Pass  49: suminf.    3.00000 (6) obj. 345133 iterations 117
# Cbc0038I Pass  50: suminf.    3.00000 (9) obj. 345134 iterations 141
# Cbc0038I Pass  51: suminf.    3.00000 (9) obj. 345134 iterations 59
# Cbc0038I Pass  52: suminf.    3.00000 (6) obj. 345131 iterations 190
# Cbc0038I Pass  53: suminf.    2.72225 (9) obj. 345134 iterations 102
# Cbc0038I Pass  54: suminf.    2.60932 (9) obj. 345134 iterations 137
# Cbc0038I Pass  55: suminf.    3.00000 (6) obj. 345131 iterations 174
# Cbc0038I Pass  56: suminf.    3.00000 (6) obj. 345131 iterations 72
# Cbc0038I Pass  57: suminf.    3.00000 (6) obj. 345131 iterations 37
# Cbc0038I Pass  58: suminf.    3.00000 (6) obj. 345131 iterations 4
# Cbc0038I Pass  59: suminf.    3.00000 (6) obj. 345131 iterations 73
# Cbc0038I Pass  60: suminf.    4.28047 (12) obj. 345134 iterations 149
# Cbc0038I Pass  61: suminf.    3.00000 (6) obj. 345133 iterations 154
# Cbc0038I Pass  62: suminf.    3.00000 (6) obj. 345133 iterations 41
# Cbc0038I Pass  63: suminf.    3.00000 (6) obj. 345133 iterations 1
# Cbc0038I Pass  64: suminf.    3.00000 (6) obj. 345133 iterations 101
# Cbc0038I Pass  65: suminf.    4.82939 (21) obj. 345134 iterations 165
# Cbc0038I Pass  66: suminf.    3.00000 (6) obj. 345134 iterations 192
# Cbc0038I Pass  67: suminf.    3.00000 (6) obj. 345134 iterations 132
# Cbc0038I Pass  68: suminf.    3.00000 (6) obj. 345134 iterations 114
# Cbc0038I Pass  69: suminf.    3.12626 (17) obj. 345134 iterations 216
# Cbc0038I Pass  70: suminf.    3.00000 (6) obj. 345134 iterations 179
# Cbc0038I Pass  71: suminf.    3.00000 (6) obj. 345134 iterations 98
# Cbc0038I Pass  72: suminf.    3.00000 (9) obj. 345134 iterations 78
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 32561 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 256 rows 32640 columns, reduced to 16 rows 34 columns
# Cbc0038I Mini branch and bound improved solution from 345136 to 345135 (2.90 seconds)
# Cbc0038I Round again with cutoff of 345133
# Cbc0038I Reduced cost fixing fixed 29711 variables on major pass 5
# Cbc0038I Pass  72: suminf.    3.00000 (6) obj. 345131 iterations 0
# Cbc0038I Pass  73: suminf.    3.00000 (6) obj. 345131 iterations 86
# Cbc0038I Pass  74: suminf.    3.00000 (6) obj. 345131 iterations 151
# Cbc0038I Pass  75: suminf.    3.00000 (6) obj. 345131 iterations 45
# Cbc0038I Pass  76: suminf.    3.00000 (6) obj. 345131 iterations 48
# Cbc0038I Pass  77: suminf.    4.93487 (15) obj. 345133 iterations 157
# Cbc0038I Pass  78: suminf.    3.81072 (13) obj. 345133 iterations 134
# Cbc0038I Pass  79: suminf.    3.00000 (6) obj. 345131 iterations 152
# Cbc0038I Pass  80: suminf.    3.00000 (6) obj. 345131 iterations 74
# Cbc0038I Pass  81: suminf.    3.00000 (6) obj. 345131 iterations 37
# Cbc0038I Pass  82: suminf.    3.00000 (6) obj. 345131 iterations 30
# Cbc0038I Pass  83: suminf.    4.00000 (11) obj. 345133 iterations 154
# Cbc0038I Pass  84: suminf.    3.00000 (9) obj. 345133 iterations 108
# Cbc0038I Pass  85: suminf.    3.00000 (9) obj. 345133 iterations 11
# Cbc0038I Pass  86: suminf.    3.00000 (6) obj. 345133 iterations 153
# Cbc0038I Pass  87: suminf.    3.28920 (11) obj. 345133 iterations 136
# Cbc0038I Pass  88: suminf.    3.00000 (9) obj. 345133 iterations 119
# Cbc0038I Pass  89: suminf.    3.00000 (6) obj. 345133 iterations 188
# Cbc0038I Pass  90: suminf.    3.00000 (6) obj. 345133 iterations 83
# Cbc0038I Pass  91: suminf.    3.00000 (6) obj. 345133 iterations 69
# Cbc0038I Pass  92: suminf.    3.00000 (9) obj. 345133 iterations 208
# Cbc0038I Pass  93: suminf.    3.00000 (9) obj. 345133 iterations 231
# Cbc0038I Pass  94: suminf.    3.00000 (9) obj. 345133 iterations 120
# Cbc0038I Pass  95: suminf.    3.00000 (6) obj. 345133 iterations 189
# Cbc0038I Pass  96: suminf.    3.00000 (6) obj. 345133 iterations 65
# Cbc0038I Pass  97: suminf.    3.00000 (6) obj. 345133 iterations 21
# Cbc0038I Pass  98: suminf.    3.00000 (6) obj. 345133 iterations 56
# Cbc0038I Pass  99: suminf.    3.37595 (12) obj. 345133 iterations 139
# Cbc0038I Pass 100: suminf.    3.00000 (6) obj. 345133 iterations 112
# Cbc0038I Pass 101: suminf.    3.00000 (6) obj. 345133 iterations 104
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 32573 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (3.54 seconds)
# Cbc0038I After 3.54 seconds - Feasibility pump exiting with objective of 345135 - took 2.68 seconds
# Cbc0012I Integer solution of 345134.66 found by feasibility pump after 0 iterations and 0 nodes (3.55 seconds)
# Cbc0012I Integer solution of 345130.63 found by DiveCoefficient after 0 iterations and 0 nodes (3.61 seconds)
# Cbc0038I Full problem 256 rows 32640 columns, reduced to 0 rows 0 columns
# Cbc0012I Integer solution of 345130.51 found by DiveCoefficient after 3 iterations and 0 nodes (3.70 seconds)
# Cbc0031I 2 added rows had average density of 3.5
# Cbc0013I At root node, 2 cuts changed objective from 345130.48 to 345130.51 in 2 passes
# Cbc0014I Cut generator 0 (Probing) - 1 row cuts average 2.0 elements, 20 column cuts (20 active)  in 0.010 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 4 row cuts average 6.0 elements, 0 column cuts (0 active)  in 0.002 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.029 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 4 row cuts average 3.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is 1
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.003 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0001I Search completed - best objective 345130.5142943077, took 3 iterations and 0 nodes (3.71 seconds)
# Cbc0035I Maximum depth 0, 31956 variables fixed on reduced cost
# Cuts at root node changed objective from 345130 to 345131
# Probing was tried 2 times and created 21 cuts of which 0 were active after adding rounds of cuts (0.010 seconds)
# Gomory was tried 2 times and created 4 cuts of which 0 were active after adding rounds of cuts (0.002 seconds)
# Knapsack was tried 2 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.029 seconds)
# Clique was tried 2 times and created 4 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# MixedIntegerRounding2 was tried 2 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.003 seconds)
# FlowCover was tried 2 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# TwoMirCuts was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.003 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.002 seconds)
#
# Result - Optimal solution found
#
# Objective value:                -345130.51429431
# Enumerated nodes:               0
# Total iterations:               3
# Time (CPU seconds):             3.68
# Time (Wallclock seconds):       3.75
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       3.77   (Wallclock seconds):       3.85
#
# lambda= 110000
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/mehr/anaconda3/lib/python3.9/site-packages/pulp/apis/../solverdir/cbc/linux/64/cbc /tmp/79b6ddc493eb4bd183487a829e02ac0f-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/79b6ddc493eb4bd183487a829e02ac0f-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 261 COLUMNS
# At line 163462 RHS
# At line 163719 BOUNDS
# At line 196360 ENDATA
# Problem MODEL has 256 rows, 32640 columns and 65280 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is -395658 - 0.32 seconds
# Cgl0004I processed model has 256 rows, 32640 columns (32640 integer (32640 of which binary)) and 65280 elements
# Cbc0038I Initial state - 6 integers unsatisfied sum - 3
# Cbc0038I Pass   1: suminf.    0.00000 (0) obj. 395776 iterations 415
# Cbc0038I Solution found of 395776
# Cbc0038I Before mini branch and bound, 32633 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 256 rows 32640 columns, reduced to 0 rows 0 columns
# Cbc0038I Mini branch and bound did not improve solution (1.00 seconds)
# Cbc0038I Round again with cutoff of 395764
# Cbc0038I Reduced cost fixing fixed 13084 variables on major pass 2
# Cbc0038I Pass   2: suminf.    3.00000 (6) obj. 395658 iterations 109
# Cbc0038I Pass   3: suminf.    0.00000 (0) obj. 395737 iterations 71
# Cbc0038I Solution found of 395737
# Cbc0038I Before mini branch and bound, 32633 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 256 rows 32640 columns, reduced to 0 rows 0 columns
# Cbc0038I Mini branch and bound did not improve solution (1.10 seconds)
# Cbc0038I Round again with cutoff of 395721
# Cbc0038I Reduced cost fixing fixed 16051 variables on major pass 3
# Cbc0038I Pass   4: suminf.    3.00000 (6) obj. 395658 iterations 0
# Cbc0038I Pass   5: suminf.    3.00000 (6) obj. 395688 iterations 153
# Cbc0038I Pass   6: suminf.    0.00000 (0) obj. 395677 iterations 70
# Cbc0038I Solution found of 395677
# Cbc0038I Before mini branch and bound, 32630 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 256 rows 32640 columns, reduced to 0 rows 0 columns
# Cbc0038I Mini branch and bound did not improve solution (1.21 seconds)
# Cbc0038I Round again with cutoff of 395671
# Cbc0038I Reduced cost fixing fixed 24624 variables on major pass 4
# Cbc0038I Pass   7: suminf.    3.00000 (6) obj. 395658 iterations 0
# Cbc0038I Pass   8: suminf.    3.00000 (6) obj. 395658 iterations 84
# Cbc0038I Pass   9: suminf.    0.00000 (0) obj. 395670 iterations 27
# Cbc0038I Solution found of 395670
# Cbc0038I Before mini branch and bound, 32628 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 256 rows 32640 columns, reduced to 0 rows 0 columns
# Cbc0038I Mini branch and bound did not improve solution (1.31 seconds)
# Cbc0038I Round again with cutoff of 395667
# Cbc0038I Reduced cost fixing fixed 25996 variables on major pass 5
# Cbc0038I Pass  10: suminf.    3.00000 (6) obj. 395658 iterations 0
# Cbc0038I Pass  11: suminf.    3.00000 (6) obj. 395659 iterations 191
# Cbc0038I Pass  12: suminf.    3.00000 (6) obj. 395659 iterations 149
# Cbc0038I Pass  13: suminf.    3.00000 (6) obj. 395659 iterations 33
# Cbc0038I Pass  14: suminf.    3.00000 (6) obj. 395659 iterations 42
# Cbc0038I Pass  15: suminf.    3.00000 (6) obj. 395659 iterations 103
# Cbc0038I Pass  16: suminf.    6.73690 (19) obj. 395667 iterations 216
# Cbc0038I Pass  17: suminf.    3.00000 (9) obj. 395667 iterations 203
# Cbc0038I Pass  18: suminf.    3.00000 (9) obj. 395667 iterations 31
# Cbc0038I Pass  19: suminf.    3.00000 (9) obj. 395667 iterations 32
# Cbc0038I Pass  20: suminf.    3.58708 (11) obj. 395667 iterations 219
# Cbc0038I Pass  21: suminf.    3.47907 (11) obj. 395667 iterations 143
# Cbc0038I Pass  22: suminf.    3.46617 (11) obj. 395667 iterations 278
# Cbc0038I Pass  23: suminf.    3.00000 (9) obj. 395667 iterations 191
# Cbc0038I Pass  24: suminf.    3.00000 (6) obj. 395662 iterations 117
# Cbc0038I Pass  25: suminf.    3.00000 (6) obj. 395662 iterations 147
# Cbc0038I Pass  26: suminf.    3.00000 (6) obj. 395662 iterations 140
# Cbc0038I Pass  27: suminf.    3.00000 (6) obj. 395662 iterations 126
# Cbc0038I Pass  28: suminf.    3.00000 (6) obj. 395662 iterations 64
# Cbc0038I Pass  29: suminf.    3.00000 (6) obj. 395662 iterations 145
# Cbc0038I Pass  30: suminf.    6.33807 (19) obj. 395667 iterations 250
# Cbc0038I Pass  31: suminf.    3.00000 (6) obj. 395662 iterations 188
# Cbc0038I Pass  32: suminf.    3.00000 (6) obj. 395662 iterations 137
# Cbc0038I Pass  33: suminf.    3.00000 (6) obj. 395662 iterations 156
# Cbc0038I Pass  34: suminf.    3.00000 (6) obj. 395662 iterations 120
# Cbc0038I Pass  35: suminf.    3.00000 (6) obj. 395662 iterations 269
# Cbc0038I Pass  36: suminf.    3.00000 (6) obj. 395662 iterations 100
# Cbc0038I Pass  37: suminf.    4.85785 (13) obj. 395667 iterations 245
# Cbc0038I Pass  38: suminf.    3.00000 (9) obj. 395667 iterations 262
# Cbc0038I Pass  39: suminf.    3.00000 (9) obj. 395667 iterations 6
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 32563 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (2.09 seconds)
# Cbc0038I After 2.09 seconds - Feasibility pump exiting with objective of 395670 - took 1.22 seconds
# Cbc0012I Integer solution of 395670.35 found by feasibility pump after 0 iterations and 0 nodes (2.10 seconds)
# Cbc0012I Integer solution of 395658.63 found by DiveCoefficient after 0 iterations and 0 nodes (2.25 seconds)
# Cbc0038I Full problem 256 rows 32640 columns, reduced to 0 rows 0 columns
# Cbc0012I Integer solution of 395658.63 found by RINS after 0 iterations and 0 nodes (2.29 seconds)
# Cbc0012I Integer solution of 395658.62 found by DiveCoefficient after 11 iterations and 0 nodes (2.36 seconds)
# Cbc0031I 2 added rows had average density of 5.5
# Cbc0013I At root node, 2 cuts changed objective from 395658.47 to 395658.62 in 2 passes
# Cbc0014I Cut generator 0 (Probing) - 33 row cuts average 2.0 elements, 25 column cuts (25 active)  in 0.012 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 1 row cuts average 8.0 elements, 0 column cuts (0 active)  in 0.002 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.028 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 1 row cuts average 3.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is 1
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.003 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0001I Search completed - best objective 395658.6248206507, took 11 iterations and 0 nodes (2.37 seconds)
# Cbc0035I Maximum depth 0, 31635 variables fixed on reduced cost
# Cuts at root node changed objective from 395658 to 395659
# Probing was tried 2 times and created 58 cuts of which 0 were active after adding rounds of cuts (0.012 seconds)
# Gomory was tried 2 times and created 1 cuts of which 0 were active after adding rounds of cuts (0.002 seconds)
# Knapsack was tried 2 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.028 seconds)
# Clique was tried 2 times and created 1 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# MixedIntegerRounding2 was tried 2 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.003 seconds)
# FlowCover was tried 2 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# TwoMirCuts was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.003 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.002 seconds)
#
# Result - Optimal solution found
#
# Objective value:                -395658.62482065
# Enumerated nodes:               0
# Total iterations:               11
# Time (CPU seconds):             2.37
# Time (Wallclock seconds):       2.40
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       2.45   (Wallclock seconds):       2.50
#
# lambda= 120000
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/mehr/anaconda3/lib/python3.9/site-packages/pulp/apis/../solverdir/cbc/linux/64/cbc /tmp/44bc347b7c154bbb892dd844dc501069-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/44bc347b7c154bbb892dd844dc501069-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 261 COLUMNS
# At line 163462 RHS
# At line 163719 BOUNDS
# At line 196360 ENDATA
# Problem MODEL has 256 rows, 32640 columns and 65280 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is -445563 - 0.35 seconds
# Cgl0004I processed model has 256 rows, 32640 columns (32640 integer (32640 of which binary)) and 65280 elements
# Cbc0038I Initial state - 10 integers unsatisfied sum - 5
# Cbc0038I Pass   1: suminf.    0.00000 (0) obj. 445942 iterations 592
# Cbc0038I Solution found of 445942
# Cbc0038I Before mini branch and bound, 32625 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 256 rows 32640 columns, reduced to 10 rows 15 columns
# Cbc0038I Mini branch and bound improved solution from 445942 to 445635 (1.15 seconds)
# Cbc0038I Round again with cutoff of 445628
# Cbc0038I Reduced cost fixing fixed 15850 variables on major pass 2
# Cbc0038I Pass   2: suminf.    0.00000 (0) obj. 445610 iterations 170
# Cbc0038I Solution found of 445610
# Cbc0038I Before mini branch and bound, 32627 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 256 rows 32640 columns, reduced to 0 rows 0 columns
# Cbc0038I Mini branch and bound improved solution from 445610 to 445593 (1.24 seconds)
# Cbc0038I Round again with cutoff of 445587
# Cbc0038I Reduced cost fixing fixed 21447 variables on major pass 3
# Cbc0038I Pass   3: suminf.    4.00000 (8) obj. 445584 iterations 224
# Cbc0038I Pass   4: suminf.    3.10846 (9) obj. 445587 iterations 412
# Cbc0038I Pass   5: suminf.    3.10846 (9) obj. 445587 iterations 15
# Cbc0038I Pass   6: suminf.    3.00000 (9) obj. 445587 iterations 265
# Cbc0038I Pass   7: suminf.    3.00000 (6) obj. 445586 iterations 127
# Cbc0038I Pass   8: suminf.    2.61934 (7) obj. 445587 iterations 179
# Cbc0038I Pass   9: suminf.    0.00000 (0) obj. 445581 iterations 249
# Cbc0038I Solution found of 445581
# Cbc0038I Before mini branch and bound, 32619 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 256 rows 32640 columns, reduced to 0 rows 0 columns
# Cbc0038I Mini branch and bound improved solution from 445581 to 445573 (1.57 seconds)
# Cbc0038I Round again with cutoff of 445570
# Cbc0038I Reduced cost fixing fixed 25717 variables on major pass 4
# Cbc0038I Pass  10: suminf.    3.00000 (6) obj. 445564 iterations 18
# Cbc0038I Pass  11: suminf.    0.00000 (0) obj. 445565 iterations 93
# Cbc0038I Solution found of 445565
# Cbc0038I Before mini branch and bound, 32628 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 256 rows 32640 columns, reduced to 0 rows 0 columns
# Cbc0038I Mini branch and bound did not improve solution (1.66 seconds)
# Cbc0038I Round again with cutoff of 445565
# Cbc0038I Reduced cost fixing fixed 28757 variables on major pass 5
# Cbc0038I Pass  12: suminf.    3.00000 (6) obj. 445564 iterations 0
# Cbc0038I Pass  13: suminf.    3.00000 (6) obj. 445564 iterations 109
# Cbc0038I Pass  14: suminf.    3.00000 (6) obj. 445564 iterations 23
# Cbc0038I Pass  15: suminf.    3.00000 (6) obj. 445564 iterations 138
# Cbc0038I Pass  16: suminf.    4.00000 (8) obj. 445565 iterations 155
# Cbc0038I Pass  17: suminf.    3.99408 (9) obj. 445565 iterations 259
# Cbc0038I Pass  18: suminf.    3.99408 (9) obj. 445565 iterations 0
# Cbc0038I Pass  19: suminf.    3.99408 (9) obj. 445565 iterations 0
# Cbc0038I Pass  20: suminf.    3.00000 (6) obj. 445564 iterations 117
# Cbc0038I Pass  21: suminf.    3.00000 (6) obj. 445564 iterations 9
# Cbc0038I Pass  22: suminf.    3.00000 (6) obj. 445564 iterations 1
# Cbc0038I Pass  23: suminf.    3.00000 (6) obj. 445564 iterations 7
# Cbc0038I Pass  24: suminf.   10.00000 (20) obj. 445565 iterations 123
# Cbc0038I Pass  25: suminf.    3.00000 (6) obj. 445564 iterations 147
# Cbc0038I Pass  26: suminf.    3.00000 (6) obj. 445564 iterations 13
# Cbc0038I Pass  27: suminf.    3.00000 (6) obj. 445564 iterations 12
# Cbc0038I Pass  28: suminf.    3.32390 (17) obj. 445565 iterations 247
# Cbc0038I Pass  29: suminf.    3.00000 (6) obj. 445565 iterations 170
# Cbc0038I Pass  30: suminf.    3.00000 (6) obj. 445565 iterations 4
# Cbc0038I Pass  31: suminf.    3.73819 (25) obj. 445565 iterations 185
# Cbc0038I Pass  32: suminf.    3.00000 (6) obj. 445565 iterations 212
# Cbc0038I Pass  33: suminf.    4.24414 (10) obj. 445565 iterations 221
# Cbc0038I Pass  34: suminf.    3.00000 (6) obj. 445565 iterations 236
# Cbc0038I Pass  35: suminf.    3.00000 (6) obj. 445565 iterations 173
# Cbc0038I Pass  36: suminf.    3.00000 (6) obj. 445565 iterations 196
# Cbc0038I Pass  37: suminf.    3.77069 (10) obj. 445565 iterations 196
# Cbc0038I Pass  38: suminf.    3.00000 (6) obj. 445565 iterations 152
# Cbc0038I Pass  39: suminf.    3.00000 (6) obj. 445565 iterations 0
# Cbc0038I Pass  40: suminf.    3.00000 (6) obj. 445565 iterations 2
# Cbc0038I Pass  41: suminf.    3.33897 (18) obj. 445565 iterations 213
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 32554 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (2.33 seconds)
# Cbc0038I After 2.34 seconds - Feasibility pump exiting with objective of 445565 - took 1.43 seconds
# Cbc0012I Integer solution of 445565.16 found by feasibility pump after 0 iterations and 0 nodes (2.34 seconds)
# Cbc0038I Full problem 256 rows 32640 columns, reduced to 2 rows 3 columns
# Cbc0038I Full problem 256 rows 32640 columns, reduced to 0 rows 0 columns
# Cbc0006I The LP relaxation is infeasible or too expensive
# Cbc0013I At root node, 0 cuts changed objective from 445563.44 to 445563.44 in 1 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 10 column cuts (10 active)  in 0.020 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 7 (ZeroHalf) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0001I Search completed - best objective 445565.1631152202, took 0 iterations and 0 nodes (2.47 seconds)
# Cbc0035I Maximum depth 0, 28491 variables fixed on reduced cost
# Cuts at root node changed objective from 445563 to 445563
# Probing was tried 1 times and created 10 cuts of which 0 were active after adding rounds of cuts (0.020 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                -445565.16311522
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             2.47
# Time (Wallclock seconds):       2.50
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       2.56   (Wallclock seconds):       2.59
#
# lambda= 130000
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/mehr/anaconda3/lib/python3.9/site-packages/pulp/apis/../solverdir/cbc/linux/64/cbc /tmp/8544aee3ba5c40c7a19837635d2921c8-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/8544aee3ba5c40c7a19837635d2921c8-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 261 COLUMNS
# At line 163462 RHS
# At line 163719 BOUNDS
# At line 196360 ENDATA
# Problem MODEL has 256 rows, 32640 columns and 65280 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is -494776 - 0.37 seconds
# Cgl0004I processed model has 256 rows, 32640 columns (32640 integer (32640 of which binary)) and 65280 elements
# Cbc0038I Initial state - 8 integers unsatisfied sum - 4
# Cbc0038I Pass   1: suminf.    0.00000 (0) obj. 496305 iterations 525
# Cbc0038I Solution found of 496305
# Cbc0038I Before mini branch and bound, 32628 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 256 rows 32640 columns, reduced to 8 rows 12 columns
# Cbc0038I Mini branch and bound improved solution from 496305 to 495158 (1.13 seconds)
# Cbc0038I Round again with cutoff of 495120
# Cbc0038I Reduced cost fixing fixed 8014 variables on major pass 2
# Cbc0038I Pass   2: suminf.    0.00000 (0) obj. 494818 iterations 336
# Cbc0038I Solution found of 494818
# Cbc0038I Before mini branch and bound, 32631 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 256 rows 32640 columns, reduced to 0 rows 0 columns
# Cbc0038I Mini branch and bound did not improve solution (1.28 seconds)
# Cbc0038I Round again with cutoff of 494810
# Cbc0038I Reduced cost fixing fixed 19509 variables on major pass 3
# Cbc0038I Pass   3: suminf.    3.00000 (6) obj. 494779 iterations 29
# Cbc0038I Pass   4: suminf.    3.00000 (6) obj. 494779 iterations 44
# Cbc0038I Pass   5: suminf.    3.00000 (6) obj. 494779 iterations 6
# Cbc0038I Pass   6: suminf.    3.00000 (6) obj. 494779 iterations 352
# Cbc0038I Pass   7: suminf.    3.00000 (6) obj. 494779 iterations 163
# Cbc0038I Pass   8: suminf.    3.00000 (6) obj. 494779 iterations 219
# Cbc0038I Pass   9: suminf.    3.00000 (6) obj. 494779 iterations 141
# Cbc0038I Pass  10: suminf.    3.00000 (6) obj. 494779 iterations 6
# Cbc0038I Pass  11: suminf.    3.00000 (6) obj. 494779 iterations 333
# Cbc0038I Pass  12: suminf.    3.00000 (6) obj. 494779 iterations 89
# Cbc0038I Pass  13: suminf.    3.00000 (6) obj. 494779 iterations 16
# Cbc0038I Pass  14: suminf.    3.00000 (6) obj. 494779 iterations 60
# Cbc0038I Pass  15: suminf.    3.00000 (6) obj. 494779 iterations 165
# Cbc0038I Pass  16: suminf.    3.00000 (6) obj. 494779 iterations 18
# Cbc0038I Pass  17: suminf.    9.94112 (29) obj. 494810 iterations 291
# Cbc0038I Pass  18: suminf.    3.52907 (11) obj. 494810 iterations 367
# Cbc0038I Pass  19: suminf.    3.00000 (6) obj. 494802 iterations 501
# Cbc0038I Pass  20: suminf.    3.00000 (6) obj. 494802 iterations 144
# Cbc0038I Pass  21: suminf.    3.00000 (6) obj. 494802 iterations 25
# Cbc0038I Pass  22: suminf.    8.58027 (36) obj. 494810 iterations 295
# Cbc0038I Pass  23: suminf.    3.00000 (6) obj. 494803 iterations 340
# Cbc0038I Pass  24: suminf.    3.00000 (6) obj. 494803 iterations 173
# Cbc0038I Pass  25: suminf.    3.00000 (6) obj. 494803 iterations 204
# Cbc0038I Pass  26: suminf.    3.00000 (6) obj. 494803 iterations 167
# Cbc0038I Pass  27: suminf.   13.82133 (41) obj. 494810 iterations 335
# Cbc0038I Pass  28: suminf.    3.00000 (9) obj. 494810 iterations 253
# Cbc0038I Pass  29: suminf.    3.00000 (9) obj. 494810 iterations 1
# Cbc0038I Pass  30: suminf.    3.00000 (6) obj. 494808 iterations 401
# Cbc0038I Pass  31: suminf.    3.00000 (9) obj. 494810 iterations 184
# Cbc0038I Pass  32: suminf.    3.00000 (9) obj. 494810 iterations 29
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 32499 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 256 rows 32640 columns, reduced to 28 rows 57 columns
# Cbc0038I Mini branch and bound improved solution from 494818 to 494811 (2.29 seconds)
# Cbc0038I Round again with cutoff of 494800
# Cbc0038I Reduced cost fixing fixed 21455 variables on major pass 4
# Cbc0038I Pass  32: suminf.    3.00000 (6) obj. 494779 iterations 0
# Cbc0038I Pass  33: suminf.    3.00000 (6) obj. 494780 iterations 172
# Cbc0038I Pass  34: suminf.    3.00000 (6) obj. 494780 iterations 231
# Cbc0038I Pass  35: suminf.    3.00000 (6) obj. 494780 iterations 154
# Cbc0038I Pass  36: suminf.    6.22558 (28) obj. 494800 iterations 271
# Cbc0038I Pass  37: suminf.    3.00000 (6) obj. 494794 iterations 330
# Cbc0038I Pass  38: suminf.    3.00000 (6) obj. 494794 iterations 1
# Cbc0038I Pass  39: suminf.    3.00000 (6) obj. 494794 iterations 148
# Cbc0038I Pass  40: suminf.   14.22121 (41) obj. 494800 iterations 321
# Cbc0038I Pass  41: suminf.    3.00000 (6) obj. 494794 iterations 467
# Cbc0038I Pass  42: suminf.    3.00000 (9) obj. 494800 iterations 177
# Cbc0038I Pass  43: suminf.    3.00000 (6) obj. 494798 iterations 432
# Cbc0038I Pass  44: suminf.    3.00000 (6) obj. 494794 iterations 169
# Cbc0038I Pass  45: suminf.    3.00000 (6) obj. 494794 iterations 251
# Cbc0038I Pass  46: suminf.    3.00000 (6) obj. 494794 iterations 122
# Cbc0038I Pass  47: suminf.    5.01773 (21) obj. 494800 iterations 288
# Cbc0038I Pass  48: suminf.    3.00000 (6) obj. 494795 iterations 241
# Cbc0038I Pass  49: suminf.    3.00000 (6) obj. 494795 iterations 160
# Cbc0038I Pass  50: suminf.    3.00000 (6) obj. 494795 iterations 260
# Cbc0038I Pass  51: suminf.    3.00000 (6) obj. 494795 iterations 146
# Cbc0038I Pass  52: suminf.    3.00000 (6) obj. 494795 iterations 82
# Cbc0038I Pass  53: suminf.    3.00000 (6) obj. 494795 iterations 155
# Cbc0038I Pass  54: suminf.    3.00000 (6) obj. 494795 iterations 160
# Cbc0038I Pass  55: suminf.    3.00000 (6) obj. 494795 iterations 256
# Cbc0038I Pass  56: suminf.    3.00000 (6) obj. 494795 iterations 163
# Cbc0038I Pass  57: suminf.    3.31753 (10) obj. 494800 iterations 375
# Cbc0038I Pass  58: suminf.    3.05694 (11) obj. 494800 iterations 139
# Cbc0038I Pass  59: suminf.    3.00000 (6) obj. 494792 iterations 377
# Cbc0038I Pass  60: suminf.    3.00000 (6) obj. 494792 iterations 124
# Cbc0038I Pass  61: suminf.    3.00000 (6) obj. 494792 iterations 11
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 32461 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (3.44 seconds)
# Cbc0038I After 3.44 seconds - Feasibility pump exiting with objective of 494811 - took 2.54 seconds
# Cbc0012I Integer solution of 494811.12 found by feasibility pump after 0 iterations and 0 nodes (3.45 seconds)
# Cbc0038I Full problem 256 rows 32640 columns, reduced to 0 rows 0 columns
# Cbc0012I Integer solution of 494782.51 found by DiveCoefficient after 37 iterations and 0 nodes (3.84 seconds)
# Cbc0031I 5 added rows had average density of 382.4
# Cbc0013I At root node, 5 cuts changed objective from 494776.42 to 494782.51 in 3 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 11 column cuts (11 active)  in 0.209 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 6 row cuts average 382.7 elements, 0 column cuts (0 active)  in 0.022 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.012 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 2 row cuts average 3.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is 1
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.004 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0001I Search completed - best objective 494782.5136562469, took 37 iterations and 0 nodes (3.85 seconds)
# Cbc0035I Maximum depth 0, 20384 variables fixed on reduced cost
# Cuts at root node changed objective from 494776 to 494783
# Probing was tried 3 times and created 11 cuts of which 0 were active after adding rounds of cuts (0.209 seconds)
# Gomory was tried 3 times and created 6 cuts of which 0 were active after adding rounds of cuts (0.022 seconds)
# Knapsack was tried 3 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.012 seconds)
# Clique was tried 3 times and created 2 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# MixedIntegerRounding2 was tried 3 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.004 seconds)
# FlowCover was tried 3 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# TwoMirCuts was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.003 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.002 seconds)
#
# Result - Optimal solution found
#
# Objective value:                -494782.51365625
# Enumerated nodes:               0
# Total iterations:               37
# Time (CPU seconds):             3.84
# Time (Wallclock seconds):       3.88
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       3.94   (Wallclock seconds):       3.99
#
# lambda= 140000
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/mehr/anaconda3/lib/python3.9/site-packages/pulp/apis/../solverdir/cbc/linux/64/cbc /tmp/2c53f2f711b44b79b04b8321341f30cf-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/2c53f2f711b44b79b04b8321341f30cf-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 261 COLUMNS
# At line 163462 RHS
# At line 163719 BOUNDS
# At line 196360 ENDATA
# Problem MODEL has 256 rows, 32640 columns and 65280 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is -543179 - 0.35 seconds
# Cgl0004I processed model has 256 rows, 32640 columns (32640 integer (32640 of which binary)) and 65280 elements
# Cbc0038I Initial state - 0 integers unsatisfied sum - 0
# Cbc0038I Solution found of 543179
# Cbc0038I Before mini branch and bound, 32640 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.91 seconds)
# Cbc0038I After 0.91 seconds - Feasibility pump exiting with objective of 543179 - took 0.03 seconds
# Cbc0012I Integer solution of 543179.02 found by feasibility pump after 0 iterations and 0 nodes (0.92 seconds)
# Cbc0001I Search completed - best objective 543179.0202452511, took 0 iterations and 0 nodes (0.92 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 543179 to 543179
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                -543179.02024525
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.94
# Time (Wallclock seconds):       0.96
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       1.05   (Wallclock seconds):       1.07
#
# lambda= 150000
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/mehr/anaconda3/lib/python3.9/site-packages/pulp/apis/../solverdir/cbc/linux/64/cbc /tmp/5ac931f2ed2e415ea4894f8becb937bd-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/5ac931f2ed2e415ea4894f8becb937bd-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 261 COLUMNS
# At line 163462 RHS
# At line 163719 BOUNDS
# At line 196360 ENDATA
# Problem MODEL has 256 rows, 32640 columns and 65280 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is -590938 - 0.35 seconds
# Cgl0004I processed model has 256 rows, 32640 columns (32640 integer (32640 of which binary)) and 65280 elements
# Cbc0038I Initial state - 8 integers unsatisfied sum - 4
# Cbc0038I Pass   1: suminf.    0.00000 (0) obj. 593889 iterations 436
# Cbc0038I Solution found of 593889
# Cbc0038I Before mini branch and bound, 32628 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 256 rows 32640 columns, reduced to 8 rows 12 columns
# Cbc0038I Mini branch and bound improved solution from 593889 to 591139 (1.11 seconds)
# Cbc0038I Round again with cutoff of 591119
# Cbc0038I Reduced cost fixing fixed 11215 variables on major pass 2
# Cbc0038I Pass   2: suminf.    3.00000 (6) obj. 590941 iterations 181
# Cbc0038I Pass   3: suminf.    3.00000 (6) obj. 590941 iterations 101
# Cbc0038I Pass   4: suminf.    3.00000 (6) obj. 591017 iterations 306
# Cbc0038I Pass   5: suminf.    3.00000 (6) obj. 591017 iterations 3
# Cbc0038I Pass   6: suminf.   12.16997 (35) obj. 591119 iterations 395
# Cbc0038I Pass   7: suminf.    3.00000 (9) obj. 591119 iterations 279
# Cbc0038I Pass   8: suminf.    3.00000 (6) obj. 591045 iterations 725
# Cbc0038I Pass   9: suminf.    3.00000 (9) obj. 591119 iterations 179
# Cbc0038I Pass  10: suminf.    3.00000 (9) obj. 591119 iterations 4
# Cbc0038I Pass  11: suminf.    3.00000 (6) obj. 591045 iterations 515
# Cbc0038I Pass  12: suminf.    3.00000 (9) obj. 591119 iterations 142
# Cbc0038I Pass  13: suminf.    3.00000 (9) obj. 591119 iterations 395
# Cbc0038I Pass  14: suminf.    3.00000 (6) obj. 591045 iterations 296
# Cbc0038I Pass  15: suminf.    3.00000 (6) obj. 591045 iterations 174
# Cbc0038I Pass  16: suminf.    7.07449 (21) obj. 591119 iterations 337
# Cbc0038I Pass  17: suminf.    3.00000 (6) obj. 591050 iterations 328
# Cbc0038I Pass  18: suminf.    3.00000 (9) obj. 591119 iterations 357
# Cbc0038I Pass  19: suminf.    3.00000 (9) obj. 591119 iterations 691
# Cbc0038I Pass  20: suminf.    3.00000 (9) obj. 591119 iterations 570
# Cbc0038I Pass  21: suminf.    3.00000 (9) obj. 591119 iterations 141
# Cbc0038I Pass  22: suminf.    4.00000 (11) obj. 591119 iterations 487
# Cbc0038I Pass  23: suminf.    3.00000 (9) obj. 591119 iterations 486
# Cbc0038I Pass  24: suminf.    3.00000 (9) obj. 591119 iterations 248
# Cbc0038I Pass  25: suminf.    3.00000 (9) obj. 591119 iterations 187
# Cbc0038I Pass  26: suminf.    3.00000 (9) obj. 591119 iterations 376
# Cbc0038I Pass  27: suminf.    4.00000 (8) obj. 591119 iterations 320
# Cbc0038I Pass  28: suminf.    3.00000 (9) obj. 591119 iterations 274
# Cbc0038I Pass  29: suminf.   13.00000 (33) obj. 591119 iterations 442
# Cbc0038I Pass  30: suminf.    4.00000 (11) obj. 591119 iterations 627
# Cbc0038I Pass  31: suminf.    4.00000 (11) obj. 591119 iterations 233
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 32442 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (2.92 seconds)
# Cbc0038I After 2.93 seconds - Feasibility pump exiting with objective of 591139 - took 2.01 seconds
# Cbc0012I Integer solution of 591138.94 found by feasibility pump after 0 iterations and 0 nodes (2.93 seconds)
# Cbc0038I Full problem 256 rows 32640 columns, reduced to 4 rows 7 columns
# Cbc0038I Full problem 256 rows 32640 columns, reduced to 0 rows 0 columns
# Cbc0012I Integer solution of 590982.39 found by DiveCoefficient after 62 iterations and 0 nodes (4.48 seconds)
# Cbc0031I 8 added rows had average density of 3689.125
# Cbc0013I At root node, 8 cuts changed objective from 590938.02 to 590982.39 in 8 passes
# Cbc0014I Cut generator 0 (Probing) - 2 row cuts average 210.0 elements, 3 column cuts (3 active)  in 1.213 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 18 row cuts average 6236.8 elements, 0 column cuts (0 active)  in 0.075 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.023 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 1 row cuts average 3.0 elements, 0 column cuts (0 active)  in 0.003 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.015 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.006 seconds - new frequency is -100
# Cbc0001I Search completed - best objective 590982.3936934071, took 62 iterations and 0 nodes (4.48 seconds)
# Cbc0035I Maximum depth 0, 11689 variables fixed on reduced cost
# Cuts at root node changed objective from 590938 to 590982
# Probing was tried 8 times and created 5 cuts of which 0 were active after adding rounds of cuts (1.213 seconds)
# Gomory was tried 8 times and created 18 cuts of which 0 were active after adding rounds of cuts (0.075 seconds)
# Knapsack was tried 8 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.023 seconds)
# Clique was tried 8 times and created 1 cuts of which 0 were active after adding rounds of cuts (0.003 seconds)
# MixedIntegerRounding2 was tried 8 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.015 seconds)
# FlowCover was tried 8 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.006 seconds)
# TwoMirCuts was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.003 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.002 seconds)
#
# Result - Optimal solution found
#
# Objective value:                -590982.39369341
# Enumerated nodes:               0
# ...
# Cbc0038I Reduced cost fixing fixed 12350 variables on major pass 3
# Cbc0038I Pass  31: suminf.    3.00000 (9) obj. 730970 iterations 7
# Cbc0038I Pass  32: suminf.    3.00000 (9) obj. 730970 iterations 143
# Cbc0038I Pass  33: suminf.    3.00000 (6) obj. 730956 iterations 523
# Cbc0038I Pass  34: suminf.    3.00000 (6) obj. 730956 iterations 179
# Cbc0038I Pass  35: suminf.    3.00000 (6) obj. 730956 iterations 215
# Cbc0038I Pass  36: suminf.    6.94666 (39) obj. 730970 iterations 391
# Cbc0038I Pass  37: suminf.    3.00000 (9) obj. 730970 iterations 323
# Cbc0038I Pass  38: suminf.    3.00000 (6) obj. 730964 iterations 543
# Cbc0038I Pass  39: suminf.    3.00000 (6) obj. 730964 iterations 163
# Cbc0038I Pass  40: suminf.    3.00000 (6) obj. 730964 iterations 148
# Cbc0038I Pass  41: suminf.    3.00000 (6) obj. 730964 iterations 209
# Cbc0038I Pass  42: suminf.    3.00000 (6) obj. 730964 iterations 254
# Cbc0038I Pass  43: suminf.    3.00000 (6) obj. 730964 iterations 122
# Cbc0038I Pass  44: suminf.    3.00000 (9) obj. 730970 iterations 186
# Cbc0038I Pass  45: suminf.    3.00000 (6) obj. 730964 iterations 475
# Cbc0038I Pass  46: suminf.    8.98277 (37) obj. 730970 iterations 360
# Cbc0038I Pass  47: suminf.    3.00000 (6) obj. 730966 iterations 459
# Cbc0038I Pass  48: suminf.    3.00000 (6) obj. 730966 iterations 90
# Cbc0038I Pass  49: suminf.    3.00000 (6) obj. 730966 iterations 67
# Cbc0038I Pass  50: suminf.   17.93269 (53) obj. 730970 iterations 371
# Cbc0038I Pass  51: suminf.    3.00000 (9) obj. 730970 iterations 370
# Cbc0038I Pass  52: suminf.    3.00000 (9) obj. 730970 iterations 1
# Cbc0038I Pass  53: suminf.    3.00000 (9) obj. 730970 iterations 16
# Cbc0038I Pass  54: suminf.    3.00000 (9) obj. 730970 iterations 28
# Cbc0038I Pass  55: suminf.    3.00000 (6) obj. 730944 iterations 527
# Cbc0038I Pass  56: suminf.    3.00000 (9) obj. 730970 iterations 136
# Cbc0038I Pass  57: suminf.    3.00000 (6) obj. 730944 iterations 564
# Cbc0038I Pass  58: suminf.    3.00000 (9) obj. 730970 iterations 163
# Cbc0038I Pass  59: suminf.    3.00000 (6) obj. 730944 iterations 549
# Cbc0038I Pass  60: suminf.   12.78296 (36) obj. 730970 iterations 384
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 32384 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 256 rows 32640 columns, reduced to 88 rows 192 columns
# Cbc0038I Mini branch and bound improved solution from 731024 to 730937 (4.10 seconds)
# Cbc0038I Round again with cutoff of 730905
# Cbc0038I Reduced cost fixing fixed 15905 variables on major pass 4
# Cbc0038I Pass  60: suminf.    3.00000 (6) obj. 730879 iterations 177
# Cbc0038I Pass  61: suminf.    3.00000 (6) obj. 730881 iterations 153
# Cbc0038I Pass  62: suminf.    3.00000 (6) obj. 730881 iterations 84
# Cbc0038I Pass  63: suminf.    3.00000 (6) obj. 730881 iterations 11
# Cbc0038I Pass  64: suminf.    3.00000 (6) obj. 730881 iterations 7
# Cbc0038I Pass  65: suminf.    8.37874 (27) obj. 730905 iterations 246
# Cbc0038I Pass  66: suminf.    3.00000 (6) obj. 730883 iterations 508
# Cbc0038I Pass  67: suminf.    3.00000 (6) obj. 730883 iterations 94
# Cbc0038I Pass  68: suminf.    3.00000 (6) obj. 730883 iterations 6
# Cbc0038I Pass  69: suminf.    5.40487 (46) obj. 730905 iterations 326
# Cbc0038I Pass  70: suminf.    3.00000 (6) obj. 730903 iterations 410
# Cbc0038I Pass  71: suminf.    3.00000 (6) obj. 730903 iterations 90
# Cbc0038I Pass  72: suminf.    3.00000 (6) obj. 730903 iterations 8
# Cbc0038I Pass  73: suminf.   12.56863 (42) obj. 730905 iterations 382
# Cbc0038I Pass  74: suminf.    4.00000 (8) obj. 730895 iterations 430
# Cbc0038I Pass  75: suminf.    3.00000 (6) obj. 730895 iterations 151
# Cbc0038I Pass  76: suminf.    3.00000 (6) obj. 730895 iterations 6
# Cbc0038I Pass  77: suminf.    8.23335 (21) obj. 730905 iterations 338
# Cbc0038I Pass  78: suminf.    3.00000 (9) obj. 730905 iterations 328
# Cbc0038I Pass  79: suminf.    3.00000 (9) obj. 730905 iterations 5
# Cbc0038I Pass  80: suminf.    3.00000 (9) obj. 730905 iterations 4
# Cbc0038I Pass  81: suminf.    3.00000 (6) obj. 730896 iterations 437
# Cbc0038I Pass  82: suminf.   10.87267 (31) obj. 730905 iterations 356
# Cbc0038I Pass  83: suminf.    5.00000 (10) obj. 730896 iterations 388
# Cbc0038I Pass  84: suminf.    3.00000 (6) obj. 730897 iterations 124
# Cbc0038I Pass  85: suminf.    3.00000 (6) obj. 730897 iterations 264
# Cbc0038I Pass  86: suminf.    3.00000 (6) obj. 730896 iterations 191
# Cbc0038I Pass  87: suminf.    3.00000 (6) obj. 730896 iterations 4
# Cbc0038I Pass  88: suminf.    7.89287 (27) obj. 730905 iterations 368
# Cbc0038I Pass  89: suminf.    3.00000 (6) obj. 730898 iterations 316
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 32357 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (5.32 seconds)
# Cbc0038I After 5.32 seconds - Feasibility pump exiting with objective of 730937 - took 4.48 seconds
# Cbc0012I Integer solution of 730937.49 found by feasibility pump after 0 iterations and 0 nodes (5.32 seconds)
# Cbc0038I Full problem 256 rows 32640 columns, reduced to 0 rows 0 columns
# Cbc0012I Integer solution of 730908.8 found by DiveCoefficient after 20 iterations and 0 nodes (6.00 seconds)
# Cbc0031I 7 added rows had average density of 115.42857
# Cbc0013I At root node, 7 cuts changed objective from 730829.55 to 730908.8 in 4 passes
# Cbc0014I Cut generator 0 (Probing) - 1 row cuts average 2.0 elements, 4 column cuts (4 active)  in 0.322 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 6 row cuts average 242.5 elements, 0 column cuts (0 active)  in 0.007 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.016 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 3 row cuts average 3.0 elements, 0 column cuts (0 active)  in 0.002 seconds - new frequency is 1
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.006 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.002 seconds - new frequency is -100
# Cbc0014I Cut generator 7 (ZeroHalf) - 4 row cuts average 307.2 elements, 0 column cuts (0 active)  in 0.012 seconds - new frequency is -100
# Cbc0001I Search completed - best objective 730908.7992342098, took 20 iterations and 0 nodes (6.00 seconds)
# Cbc0035I Maximum depth 0, 21700 variables fixed on reduced cost
# Cuts at root node changed objective from 730830 to 730909
# Probing was tried 4 times and created 5 cuts of which 0 were active after adding rounds of cuts (0.322 seconds)
# Gomory was tried 4 times and created 6 cuts of which 0 were active after adding rounds of cuts (0.007 seconds)
# Knapsack was tried 4 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.016 seconds)
# Clique was tried 4 times and created 3 cuts of which 0 were active after adding rounds of cuts (0.002 seconds)
# MixedIntegerRounding2 was tried 4 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.006 seconds)
# FlowCover was tried 4 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.002 seconds)
# TwoMirCuts was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.004 seconds)
# ZeroHalf was tried 4 times and created 4 cuts of which 0 were active after adding rounds of cuts (0.012 seconds)
#
# Result - Optimal solution found
#
# Objective value:                -730908.79923421
# Enumerated nodes:               0
# Total iterations:               20
# Time (CPU seconds):             6.02
# Time (Wallclock seconds):       6.04
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       6.12   (Wallclock seconds):       6.15
#
# lambda= 190000
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/mehr/anaconda3/lib/python3.9/site-packages/pulp/apis/../solverdir/cbc/linux/64/cbc /tmp/4a4bf7072a414e26b76306e94e36e532-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/4a4bf7072a414e26b76306e94e36e532-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 261 COLUMNS
# At line 163462 RHS
# At line 163719 BOUNDS
# At line 196360 ENDATA
# Problem MODEL has 256 rows, 32640 columns and 65280 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is -774728 - 0.46 seconds
# Cgl0004I processed model has 256 rows, 32640 columns (32640 integer (32640 of which binary)) and 65280 elements
# Cbc0038I Initial state - 6 integers unsatisfied sum - 3
# Cbc0038I Pass   1: suminf.    0.00000 (0) obj. 775381 iterations 429
# Cbc0038I Solution found of 775381
# Cbc0038I Before mini branch and bound, 32631 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 256 rows 32640 columns, reduced to 6 rows 9 columns
# Cbc0038I Mini branch and bound improved solution from 775381 to 774927 (1.13 seconds)
# Cbc0038I Round again with cutoff of 774907
# Cbc0038I Reduced cost fixing fixed 11467 variables on major pass 2
# Cbc0038I Pass   2: suminf.    3.00000 (6) obj. 774728 iterations 246
# Cbc0038I Pass   3: suminf.    3.00000 (6) obj. 774728 iterations 330
# Cbc0038I Pass   4: suminf.    3.00000 (6) obj. 774728 iterations 116
# Cbc0038I Pass   5: suminf.    3.00000 (6) obj. 774728 iterations 391
# Cbc0038I Pass   6: suminf.    0.27976 (10) obj. 774907 iterations 375
# Cbc0038I Solution found of 774906
# Cbc0038I Before mini branch and bound, 32573 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 256 rows 32640 columns, reduced to 0 rows 0 columns
# Cbc0038I Mini branch and bound improved solution from 774906 to 774905 (1.47 seconds)
# Cbc0038I Round again with cutoff of 774870
# Cbc0038I Reduced cost fixing fixed 12691 variables on major pass 3
# Cbc0038I Pass   7: suminf.    3.00000 (6) obj. 774728 iterations 0
# Cbc0038I Pass   8: suminf.    3.00000 (6) obj. 774728 iterations 376
# Cbc0038I Pass   9: suminf.    3.00000 (6) obj. 774728 iterations 146
# Cbc0038I Pass  10: suminf.    4.92427 (13) obj. 774870 iterations 343
# Cbc0038I Pass  11: suminf.    1.88437 (6) obj. 774870 iterations 398
# Cbc0038I Solution found of 774822
# Cbc0038I Before mini branch and bound, 32563 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 256 rows 32640 columns, reduced to 0 rows 0 columns
# Cbc0038I Mini branch and bound improved solution from 774822 to 774754 (1.77 seconds)
# Cbc0038I Round again with cutoff of 774746
# Cbc0038I Reduced cost fixing fixed 22649 variables on major pass 4
# Cbc0038I Pass  12: suminf.    3.00000 (6) obj. 774728 iterations 0
# Cbc0038I Pass  13: suminf.    3.00000 (6) obj. 774728 iterations 180
# Cbc0038I Pass  14: suminf.    3.00000 (6) obj. 774728 iterations 222
# Cbc0038I Pass  15: suminf.    3.00000 (6) obj. 774728 iterations 172
# Cbc0038I Pass  16: suminf.    3.00000 (6) obj. 774735 iterations 94
# Cbc0038I Pass  17: suminf.    3.00000 (6) obj. 774735 iterations 92
# Cbc0038I Pass  18: suminf.    3.00000 (6) obj. 774735 iterations 180
# Cbc0038I Pass  19: suminf.    3.00000 (6) obj. 774735 iterations 91
# Cbc0038I Pass  20: suminf.    8.49511 (23) obj. 774746 iterations 221
# Cbc0038I Pass  21: suminf.    3.32738 (11) obj. 774746 iterations 321
# Cbc0038I Pass  22: suminf.    1.86237 (7) obj. 774746 iterations 121
# Cbc0038I Pass  23: suminf.    3.00000 (6) obj. 774736 iterations 454
# Cbc0038I Pass  24: suminf.    3.00000 (6) obj. 774736 iterations 119
# Cbc0038I Pass  25: suminf.    3.00000 (6) obj. 774736 iterations 171
# Cbc0038I Pass  26: suminf.    3.00000 (6) obj. 774736 iterations 29
# Cbc0038I Pass  27: suminf.    4.07132 (15) obj. 774746 iterations 216
# Cbc0038I Pass  28: suminf.    2.00223 (7) obj. 774746 iterations 198
# Cbc0038I Pass  29: suminf.    3.00000 (6) obj. 774737 iterations 400
# Cbc0038I Pass  30: suminf.    3.00000 (6) obj. 774737 iterations 104
# Cbc0038I Pass  31: suminf.    3.00000 (6) obj. 774737 iterations 29
# Cbc0038I Pass  32: suminf.    7.00000 (14) obj. 774738 iterations 306
# Cbc0038I Pass  33: suminf.    3.00000 (6) obj. 774738 iterations 328
# Cbc0038I Pass  34: suminf.    3.00000 (6) obj. 774738 iterations 200
# Cbc0038I Pass  35: suminf.    3.00000 (6) obj. 774738 iterations 92
# Cbc0038I Pass  36: suminf.    6.10701 (19) obj. 774746 iterations 203
# Cbc0038I Pass  37: suminf.    2.12227 (7) obj. 774746 iterations 214
# Cbc0038I Pass  38: suminf.    3.00000 (6) obj. 774738 iterations 369
# Cbc0038I Pass  39: suminf.    3.00000 (6) obj. 774738 iterations 137
# Cbc0038I Pass  40: suminf.    3.00000 (6) obj. 774738 iterations 220
# Cbc0038I Pass  41: suminf.    5.93987 (19) obj. 774746 iterations 255
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 32473 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (2.70 seconds)
# Cbc0038I After 2.70 seconds - Feasibility pump exiting with objective of 774754 - took 1.73 seconds
# Cbc0012I Integer solution of 774754.3 found by feasibility pump after 0 iterations and 0 nodes (2.71 seconds)
# Cbc0012I Integer solution of 774731.44 found by DiveCoefficient after 0 iterations and 0 nodes (2.75 seconds)
# Cbc0038I Full problem 256 rows 32640 columns, reduced to 0 rows 0 columns
# Cbc0012I Integer solution of 774729.75 found by DiveCoefficient after 90 iterations and 0 nodes (3.29 seconds)
# Cbc0031I 15 added rows had average density of 198.6
# Cbc0013I At root node, 15 cuts changed objective from 774728.16 to 774729.75 in 7 passes
# Cbc0014I Cut generator 0 (Probing) - 10 row cuts average 29.5 elements, 7 column cuts (7 active)  in 0.287 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 31 row cuts average 280.8 elements, 0 column cuts (0 active)  in 0.031 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.046 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 5 row cuts average 3.0 elements, 0 column cuts (0 active)  in 0.003 seconds - new frequency is 1
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.011 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.004 seconds - new frequency is -100
# Cbc0014I Cut generator 7 (ZeroHalf) - 4 row cuts average 245.8 elements, 0 column cuts (0 active)  in 0.059 seconds - new frequency is -100
# Cbc0001I Search completed - best objective 774729.7470980021, took 90 iterations and 0 nodes (3.30 seconds)
# Cbc0035I Maximum depth 0, 24805 variables fixed on reduced cost
# Cuts at root node changed objective from 774728 to 774730
# Probing was tried 7 times and created 17 cuts of which 0 were active after adding rounds of cuts (0.287 seconds)
# Gomory was tried 7 times and created 31 cuts of which 0 were active after adding rounds of cuts (0.031 seconds)
# Knapsack was tried 7 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.046 seconds)
# Clique was tried 7 times and created 5 cuts of which 0 were active after adding rounds of cuts (0.003 seconds)
# MixedIntegerRounding2 was tried 7 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.011 seconds)
# FlowCover was tried 7 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.004 seconds)
# TwoMirCuts was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.003 seconds)
# ZeroHalf was tried 7 times and created 4 cuts of which 0 were active after adding rounds of cuts (0.059 seconds)
#
# Result - Optimal solution found
#
# Objective value:                -774729.74709800
# Enumerated nodes:               0
# Total iterations:               90
# Time (CPU seconds):             3.28
# Time (Wallclock seconds):       3.33
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       3.38   (Wallclock seconds):       3.43

# %% [markdown]
# # Reconstructions, PSNRs

# %%
for Lambda in Lambdas:
# Better MSB 0 assignment ##################################### 
    pairs_show_file_name = image_name + '_pairs_' +str(Lambda)+'.npy' 
    mip_pairs_show = np.load(pairs_show_file_name)

    pairs_show = np.transpose(mip_pairs_show)
    abs_pairs_show = abs(pairs_show)
    pair_diff = abs(abs_pairs_show [:,0] - abs_pairs_show [:,1])
    pair_diff = pair_diff[..., None]
    pairs_diff = np.append(pairs_show, pair_diff, axis = 1)
    pairs_diff_sort = pairs_diff[pairs_diff[:,2].argsort()[::-1]]

    msb0_elements = np.zeros(np.shape(mip_pairs_show)[1])
    msb1_elements = np.zeros(np.shape(mip_pairs_show)[1])

    opt_pairs_prbs = []
    opt_pairs_prbs_dic = {}

    ac_dists = []
    for i in range(0,np.shape(mip_pairs_show)[1]):
        pair1 = pairs_diff_sort[i][0]
        pos1 = np.where(ac_values_n0 == pair1)
        prb_pair1 = prbs[pos1]

        pair2 = pairs_diff_sort[i][1]
        pos2 = np.where(ac_values_n0 == pair2)
        prb_pair2 = prbs[pos2]

        if not np.mod(i,2):
            if abs(pair1) < abs(pair2):
                msb0_elements [i] = pair1
                msb1_elements [i] = pair2
            else:
                msb0_elements [i] = pair2
                msb1_elements [i] = pair1
        if np.mod(i,2):
            if abs(pair1) > abs(pair2):
                msb0_elements [i] = pair1
                msb1_elements [i] = pair2
            else:
                msb0_elements [i] = pair2
                msb1_elements [i] = pair1   


        # probability of pairs
        pair_prb = prb_pair1 + prb_pair2
        opt_pairs_prbs = np.append(opt_pairs_prbs, pair_prb)
        element1 = pair1
        opt_pairs_prbs_dic[element1] = pair_prb

        # distortion between ac pairs
        ac_dist = 0.5*(pair1-pair2)**2*pair_prb
        ac_dists = np.append(ac_dists, ac_dist)

    ac_dist_total = sum(ac_dists)
    ac_dist_total_db = 10*np.log10(ac_dist_total)
    ac_dist_total_dbs = np.append(ac_dist_total_dbs, ac_dist_total_db)


    #     ###### For Lambdas
    opt_pairs_prbs_lambda_dic [Lambda] = opt_pairs_prbs_dic


    # Reconstruction
    eve_msb0_intensities = np.zeros([height,width])
    eve_msb1_intensities = np.zeros([height,width])
    for i in range(0,int(height/8)):
        for j in range(0,int(width/8)):
            blk = imf[8*i:8*(i+1), 8*j:8*(j+1)]
            shifted_blk = blk - 128 #level_shift for dct
            dct = cv2.dct(shifted_blk)
            nq_coef = np.round(dct)
            nq_coef_ac = np.delete(nq_coef, [0,0])
            nq_coef_dc = nq_coef[0,0]

            eve_ac_msb0 = nq_coef_ac.copy()
            eve_ac_msb1 = nq_coef_ac.copy()
            for m in range(np.size(nq_coef_ac)):
                if nq_coef_ac[m] in msb0_elements:
                    eve_ac_msb0[m] =  nq_coef_ac[m]

                    pos = np.where(msb0_elements == nq_coef_ac[m])
    #                     poss = np.where(msb0_elements == nq_coef_ac[m])
    #                     pos = poss[0][0]

                    eve_ac_msb1[m] = msb1_elements[pos]
                if nq_coef_ac[m] in msb1_elements:
                    eve_ac_msb1[m] =  nq_coef_ac[m]

                    pos = np.where(msb1_elements == nq_coef_ac[m])
    #                     poss = np.where(msb1_elements == nq_coef_ac[m])
    #                     pos = poss[0][0]
                    eve_ac_msb0[m] = msb0_elements[pos]


            eve_msb0_coef1 = np.insert(eve_ac_msb0, 0, 128)
#             eve_msb0_coef1 = np.insert(eve_ac_msb0, 0, nq_coef_dc)
            eve_msb0_coef = np.reshape(eve_msb0_coef1,[8,8])

            eve_msb0_blk1 = cv2.idct(eve_msb0_coef)
            eve_msb0_blk2 = eve_msb0_blk1+128 # level_shift after idct
            eve_msb0_blk = np.round(eve_msb0_blk2)  
            eve_msb0_intensities [8*i:8*(i+1), 8*j:8*(j+1)]= eve_msb0_blk


            eve_msb1_coef1 = np.insert(eve_ac_msb1, 0, 128)
#             eve_msb1_coef1 = np.insert(eve_ac_msb1, 0, nq_coef_dc)
            eve_msb1_coef = np.reshape(eve_msb1_coef1,[8,8])

            eve_msb1_blk1 = cv2.idct(eve_msb1_coef)
            eve_msb1_blk2 = eve_msb1_blk1+128 # level_shift after idct
            eve_msb1_blk = np.round(eve_msb1_blk2)  
            eve_msb1_intensities [8*i:8*(i+1), 8*j:8*(j+1)]= eve_msb1_blk


    eve_msb0_modified = eve_msb0_intensities.copy()
    eve_msb0_modified[eve_msb0_modified<0] = 0
    eve_msb0_modified[eve_msb0_modified>255] = 255
    #eve_msb0_uint8 = eve_msb0_intensities.astype(np.uint8)
    filename = image_name +'_msb0_'+str(Lambda)+'.png'
    cv2.imwrite(filename, eve_msb0_modified)
    
    eve_msb1_modified = eve_msb1_intensities.copy()
    eve_msb1_modified[eve_msb1_modified<0] = 0
    eve_msb1_modified[eve_msb1_modified>255] = 255
#     eve_msb1_uint8 =eve_msb1_intensities.astype(np.uint8)
    filename = image_name +'_msb1_'+str(Lambda)+'.png'
    cv2.imwrite(filename, eve_msb1_modified)

    # Distortion
    eve_msb0_dist_db = 10*np.log10(eve_distortion(eve_msb0_modified))
    eve_msb1_dist_db = 10*np.log10(eve_distortion(eve_msb1_modified))

    psnr_msb0_db = 20*np.log10(255)-eve_msb0_dist_db
    psnr_msb1_db = 20*np.log10(255)-eve_msb1_dist_db

    avg_psnr = \
    20*np.log10(255)-10*np.log10((eve_distortion(eve_msb0_modified)
                                 +eve_distortion(eve_msb1_modified))/2)
    avg_psnrs = np.append(avg_psnrs, avg_psnr)
    psnr_msb0s = np.append(psnr_msb0s, psnr_msb0_db)
    psnr_msb1s = np.append(psnr_msb1s, psnr_msb1_db)
# Out:
# /tmp/ipykernel_7258/4134898774.py:2: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   feve_intensities = eve_intensities.astype(np.float)
# /tmp/ipykernel_7258/4134898774.py:3: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   fintensities = intensities.astype(np.float)
